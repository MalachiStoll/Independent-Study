# %%
# %matplotlib inline
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt 

from io import BytesIO

from scipy.misc import imread, imshow

from skimage import data

import zipfile

# %%
file = zipfile.ZipFile('Week-3-Numpy.zip', 'r')
file.namelist()
# Out:
# ['03_Numpy_Notebook.ipynb',
#  '__MACOSX/',
#  '__MACOSX/._03_Numpy_Notebook.ipynb',
#  'Satellite Image Analysis using numpy.ipynb',
#  '__MACOSX/._Satellite Image Analysis using numpy.ipynb',
#  'wifire/',
#  'wifire/.DS_Store',
#  '__MACOSX/wifire/',
#  '__MACOSX/wifire/._.DS_Store',
#  'wifire/Icon\r',
#  '__MACOSX/wifire/._Icon\r',
#  'wifire/sd-3layers.jpg',
#  '__MACOSX/wifire/._sd-3layers.jpg',
#  '__MACOSX/._wifire']

# %%
data = file.read('wifire/sd-3layers.jpg')
dataEnc = BytesIO(data)
img = imread(dataEnc)
img
# Out:
# array([[[  0,  22,  35],
#         [  0,  11,  57],
#         [ 19,  32, 128],
#         ...,
#         [ 19,  21,  98],
#         [  0,   6,  28],
#         [  0,  19,   0]],
#
#        [[ 30,  64, 109],
#         [ 29,  46, 128],
#         [ 25,  33, 157],
#         ...,
#         [  1,   5,  50],
#         [  0,   5,  34],
#         [  0,   4,  28]],
#
#        [[ 23,  57, 155],
#         [ 16,  35, 174],
#         [ 15,  24, 189],
#         ...,
#         [  0,   5,   9],
#         [  0,   5,  34],
#         [  0,   2,  69]],
#
#        ...,
#        [[  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1],
#         ...,
#         [  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1]],
#
#        [[  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1],
#         ...,
#         [  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1]],
#
#        [[  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1],
#         ...,
#         [  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1]]], dtype=uint8)

# %%
plt.imshow(img)
plt.show()
